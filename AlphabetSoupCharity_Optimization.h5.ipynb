# %% [markdown]
# <a href="https://colab.research.google.com/github/PascalineNjouwou/deep-learning-challenge/blob/main/AlphabetSoupCharity_Optimization.h5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(["EIN", "NAME"], axis=1, inplace=True)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_value_counts = application_df["APPLICATION_TYPE"].value_counts()
application_types_to_replace = []
for index, value in application_types_value_counts.items():
    if value < 500:
      application_types_to_replace.append(index)


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_value_counts = application_df["CLASSIFICATION"].value_counts()
for index, value in classification_value_counts.items():
    if value > 1:
      print(index,value)
# Out:
# C1000 17326
# C2000 6074
# C1200 4837
# C3000 1918
# C2100 1883
# C7000 777
# C1700 287
# C4000 194
# C5000 116
# C1270 114
# C2700 104
# C2800 95
# C7100 75
# C1300 58
# C1280 50
# C1230 36
# C1400 34
# C7200 32
# C2300 32
# C1240 30
# C8000 20
# C7120 18
# C1500 16
# C1800 15
# C6000 15
# C1250 14
# C8200 11
# C1238 10
# C1278 10
# C1235 9
# C1237 9
# C7210 7
# C2400 6
# C1720 6
# C4100 6
# C1257 5
# C1600 5
# C1260 3
# C2710 3
# C0 3
# C3200 2
# C1234 2
# C1246 2
# C1267 2
# C1256 2

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classification_value_counts = application_df["CLASSIFICATION"].value_counts()
classifications_to_replace = []
for index, value in classification_value_counts.items():
    if value < 1000:
      classifications_to_replace.append(index)
classifications_to_replace

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df, columns=["APPLICATION_TYPE", "CLASSIFICATION", "AFFILIATION", "USE_CASE", "ORGANIZATION", "INCOME_AMT", "SPECIAL_CONSIDERATIONS"])

# %%
# Split our preprocessed data into our features and target arrays
y = application_df.IS_SUCCESSFUL.values
X = application_df.drop(columns="IS_SUCCESSFUL").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=125, activation="relu", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=100, activation="relu"))
nn.add(tf.keras.layers.Dense(units=75, activation="relu"))
nn.add(tf.keras.layers.Dense(units=50, activation="relu"))
nn.add(tf.keras.layers.Dense(units=25, activation="relu"))
nn.add(tf.keras.layers.Dense(units=10, activation="relu"))
nn.add(tf.keras.layers.Dense(units=5, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 125)               5500
#
#  dense_8 (Dense)             (None, 100)               12600
#
#  dense_9 (Dense)             (None, 75)                7575
#
#  dense_10 (Dense)            (None, 50)                3800
#
#  dense_11 (Dense)            (None, 25)                1275
#
#  dense_12 (Dense)            (None, 10)                260
#
#  dense_13 (Dense)            (None, 5)                 55
#
#  dense_14 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 31071 (121.37 KB)
# Trainable params: 31071 (121.37 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=150)
# Out:
# Epoch 1/150
# 858/858 [==============================] - 5s 4ms/step - loss: 0.5717 - accuracy: 0.7207
# Epoch 2/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5558 - accuracy: 0.7292
# Epoch 3/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5533 - accuracy: 0.7306
# Epoch 4/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5520 - accuracy: 0.7317
# Epoch 5/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5502 - accuracy: 0.7322
# Epoch 6/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5501 - accuracy: 0.7323
# Epoch 7/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5492 - accuracy: 0.7319
# Epoch 8/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5479 - accuracy: 0.7333
# Epoch 9/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5480 - accuracy: 0.7333
# Epoch 10/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5472 - accuracy: 0.7337
# Epoch 11/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5468 - accuracy: 0.7328
# Epoch 12/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5457 - accuracy: 0.7341
# Epoch 13/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7350
# Epoch 14/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5453 - accuracy: 0.7334
# Epoch 15/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5446 - accuracy: 0.7352
# Epoch 16/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5458 - accuracy: 0.7332
# Epoch 17/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5440 - accuracy: 0.7342
# Epoch 18/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5445 - accuracy: 0.7354
# Epoch 19/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5432 - accuracy: 0.7357
# Epoch 20/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5434 - accuracy: 0.7360
# Epoch 21/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5430 - accuracy: 0.7364
# Epoch 22/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5427 - accuracy: 0.7360
# Epoch 23/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5428 - accuracy: 0.7341
# Epoch 24/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5422 - accuracy: 0.7360
# Epoch 25/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5423 - accuracy: 0.7362
# Epoch 26/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5415 - accuracy: 0.7369
# Epoch 27/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5413 - accuracy: 0.7360
# Epoch 28/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5413 - accuracy: 0.7369
# Epoch 29/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5406 - accuracy: 0.7350
# Epoch 30/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5411 - accuracy: 0.7365
# Epoch 31/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5406 - accuracy: 0.7375
# Epoch 32/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7367
# Epoch 33/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7351
# Epoch 34/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5400 - accuracy: 0.7373
# Epoch 35/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5403 - accuracy: 0.7368
# Epoch 36/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5398 - accuracy: 0.7372
# Epoch 37/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5395 - accuracy: 0.7371
# Epoch 38/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5395 - accuracy: 0.7370
# Epoch 39/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5393 - accuracy: 0.7377
# Epoch 40/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5387 - accuracy: 0.7384
# Epoch 41/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5389 - accuracy: 0.7372
# Epoch 42/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5393 - accuracy: 0.7374
# Epoch 43/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5385 - accuracy: 0.7370
# Epoch 44/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5383 - accuracy: 0.7378
# Epoch 45/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5379 - accuracy: 0.7388
# Epoch 46/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5395 - accuracy: 0.7374
# Epoch 47/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7381
# Epoch 48/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7384
# Epoch 49/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7389
# Epoch 50/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7383
# Epoch 51/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5373 - accuracy: 0.7374
# Epoch 52/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5373 - accuracy: 0.7385
# Epoch 53/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7382
# Epoch 54/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7374
# Epoch 55/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7374
# Epoch 56/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7382
# Epoch 57/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5371 - accuracy: 0.7381
# Epoch 58/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7380
# Epoch 59/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7386
# Epoch 60/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7384
# Epoch 61/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7390
# Epoch 62/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5368 - accuracy: 0.7389
# Epoch 63/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5369 - accuracy: 0.7384
# Epoch 64/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5365 - accuracy: 0.7387
# Epoch 65/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7385
# Epoch 66/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7390
# Epoch 67/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7396
# Epoch 68/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5359 - accuracy: 0.7396
# Epoch 69/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7393
# Epoch 70/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7385
# Epoch 71/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7375
# Epoch 72/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7373
# Epoch 73/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5365 - accuracy: 0.7388
# Epoch 74/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5372 - accuracy: 0.7382
# Epoch 75/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7395
# Epoch 76/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7390
# Epoch 77/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7391
# Epoch 78/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7381
# Epoch 79/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5366 - accuracy: 0.7384
# Epoch 80/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7392
# Epoch 81/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7400
# Epoch 82/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5355 - accuracy: 0.7385
# Epoch 83/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5360 - accuracy: 0.7380
# Epoch 84/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5354 - accuracy: 0.7387
# Epoch 85/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5362 - accuracy: 0.7381
# Epoch 86/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7388
# Epoch 87/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7381
# Epoch 88/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5352 - accuracy: 0.7380
# Epoch 89/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5351 - accuracy: 0.7388
# Epoch 90/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5360 - accuracy: 0.7388
# Epoch 91/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5362 - accuracy: 0.7392
# Epoch 92/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5350 - accuracy: 0.7394
# Epoch 93/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5348 - accuracy: 0.7395
# Epoch 94/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5346 - accuracy: 0.7386
# Epoch 95/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5358 - accuracy: 0.7385
# Epoch 96/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5357 - accuracy: 0.7384
# Epoch 97/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5346 - accuracy: 0.7377
# Epoch 98/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5350 - accuracy: 0.7395
# Epoch 99/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5359 - accuracy: 0.7395
# Epoch 100/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5345 - accuracy: 0.7400
# Epoch 101/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5351 - accuracy: 0.7397
# Epoch 102/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5354 - accuracy: 0.7392
# Epoch 103/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5348 - accuracy: 0.7394
# Epoch 104/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5348 - accuracy: 0.7384
# Epoch 105/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5342 - accuracy: 0.7387
# Epoch 106/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5343 - accuracy: 0.7393
# Epoch 107/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5341 - accuracy: 0.7395
# Epoch 108/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5344 - accuracy: 0.7395
# Epoch 109/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5359 - accuracy: 0.7337
# Epoch 110/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5341 - accuracy: 0.7397
# Epoch 111/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5343 - accuracy: 0.7396
# Epoch 112/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5341 - accuracy: 0.7395
# Epoch 113/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5341 - accuracy: 0.7392
# Epoch 114/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5344 - accuracy: 0.7392
# Epoch 115/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5340 - accuracy: 0.7383
# Epoch 116/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5344 - accuracy: 0.7387
# Epoch 117/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5346 - accuracy: 0.7393
# Epoch 118/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5337 - accuracy: 0.7387
# Epoch 119/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5346 - accuracy: 0.7392
# Epoch 120/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5353 - accuracy: 0.7399
# Epoch 121/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5341 - accuracy: 0.7384
# Epoch 122/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5340 - accuracy: 0.7381
# Epoch 123/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7391
# Epoch 124/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5345 - accuracy: 0.7396
# Epoch 125/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5333 - accuracy: 0.7394
# Epoch 126/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7377
# Epoch 127/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5337 - accuracy: 0.7390
# Epoch 128/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5332 - accuracy: 0.7398
# Epoch 129/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5334 - accuracy: 0.7398
# Epoch 130/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7391
# Epoch 131/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7389
# Epoch 132/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7393
# Epoch 133/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7389
# Epoch 134/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5338 - accuracy: 0.7388
# Epoch 135/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5338 - accuracy: 0.7397
# Epoch 136/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5340 - accuracy: 0.7402
# Epoch 137/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5339 - accuracy: 0.7394
# Epoch 138/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.7381
# Epoch 139/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7402
# Epoch 140/150
# 858/858 [==============================] - 3s 4ms/step - loss: 0.5335 - accuracy: 0.7399
# Epoch 141/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5338 - accuracy: 0.7391
# Epoch 142/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7396
# Epoch 143/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7401
# Epoch 144/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7399
# Epoch 145/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5338 - accuracy: 0.7392
# Epoch 146/150
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5333 - accuracy: 0.7399
# Epoch 147/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7393
# Epoch 148/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7392
# Epoch 149/150
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5336 - accuracy: 0.7392
# Epoch 150/150
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7392

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 0s - loss: 0.5735 - accuracy: 0.7286 - 468ms/epoch - 2ms/step
# Loss: 0.573519229888916, Accuracy: 0.7285714149475098

# %%
# Export our model to HDF5 file / Name the file AlphabetSoupCharity.h5
nn.save("Models/AlphabetSoupCharity_Optimization.h5", save_format="h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
